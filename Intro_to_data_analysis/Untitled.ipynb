# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import csv

# %%
with open('/Users/ryanlambert/Downloads/enrollments.csv') as f:
    reader = csv.DictReader(f)
    enrollments = list(reader)

enrollment_account_keys = [i['account_key'] for i in enrollments]
enrollment_account_keys
# Out:
# ['448',
#  '448',
#  '448',
#  '448',
#  '448',
#  '448',
#  '448',
#  '448',
#  '448',
#  '700',
#  '429',
#  '429',
#  '60',
#  '60',
#  '60',
#  '1300',
#  '369',
#  '322',
#  '322',
#  '322',
#  '322',
#  '336',
#  '553',
#  '584',
#  '584',
#  '584',
#  '1006',
#  '458',
#  '458',
#  '458',
#  '1058',
#  '1058',
#  '1058',
#  '206',
#  '45',
#  '45',
#  '315',
#  '604',
#  '204',
#  '408',
#  '408',
#  '408',
#  '51',
#  '51',
#  '323',
#  '568',
#  '130',
#  '130',
#  '130',
#  '550',
#  '550',
#  '44',
#  '44',
#  '1020',
#  '838',
#  '198',
#  '368',
#  '440',
#  '675',
#  '57',
#  '57',
#  '1090',
#  '541',
#  '756',
#  '756',
#  '1219',
#  '101',
#  '1021',
#  '1108',
#  '800',
#  '800',
#  '702',
#  '702',
#  '702',
#  '702',
#  '871',
#  '38',
#  '215',
#  '744',
#  '217',
#  '217',
#  '217',
#  '1221',
#  '1211',
#  '1211',
#  '1211',
#  '1051',
#  '1286',
#  '53',
#  '53',
#  '895',
#  '895',
#  '283',
#  '283',
#  '338',
#  '338',
#  '338',
#  '338',
#  '579',
# ...
